# %% [markdown]
# # EDA on Argentine lakes and reservoirs dataset

# %% [markdown]
# ![lake_lacar](smandes.jpg)
#
# ## Description of the problem
#
# Dsecription of the problem/questions I want to answer

# %% [markdown]
# ## Preliminary steps
#
# First of all, we import the libraries that will be using during this analysis and load the dataset into the **data** variable:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

filepath = "./lake_res_data.csv"
data = pd.read_csv(filepath)

# %% [markdown]
# Next, we will explore some characteristics of the dataset using relevant pandas methods such as **info()**, **describe()** and **head()**:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      103 non-null    int64
#  1   NAME    103 non-null    object
#  2   TYPE    103 non-null    object
#  3   AREA    103 non-null    float64
#  4   ZMEAN   103 non-null    float64
#  5   ALT     103 non-null    int64
#  6   LAT     103 non-null    float64
#  7   TEMP    103 non-null    float64
#  8   SDT     103 non-null    float64
#  9   TP      103 non-null    int64
#  10  TON     103 non-null    int64
#  11  CHL-a   103 non-null    float64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 9.8+ KB
#    ID          NAME       TYPE  AREA  ZMEAN   ALT    LAT  TEMP   SDT  TP  TON  \
# 0   1         Rodeo       lake  0.09    3.6  1446  24.12  16.0  0.85  15   63
# 1   2      Comedero       lake  0.12    4.0  1446  24.12  16.0  1.20  18   36
# 2   3    La Ciénaga  reservoir  2.80    9.3  1212  24.47  17.5  1.00  25   45
# 3   4   Las Maderas  reservoir  9.60   31.3  1185  24.45  18.0  1.40  23   35
# 4   5  Campo Alegre  reservoir  3.20   14.4  1200  24.63  19.0  1.20  58   62
#
#    CHL-a
# 0   15.4
# 1   22.5
# 2    7.4
# 3   13.3
# 4   23.7

# %%
data.describe()
# Out:
#                ID         AREA       ZMEAN          ALT         LAT  \
# count  103.000000   103.000000  103.000000   103.000000  103.000000
# mean    52.000000    73.370000   25.610680   583.776699   37.202718
# std     29.877528   234.395916   36.272095   481.896192    5.603130
# min      1.000000     0.090000    0.700000     2.000000   24.120000
# 25%     26.500000     4.350000    3.100000   159.500000   34.375000
# 50%     52.000000    12.000000    8.100000   550.000000   37.880000
# 75%     77.500000    44.300000   33.150000   844.500000   42.310000
# max    103.000000  1984.000000  166.000000  3250.000000   45.900000
#
#              TEMP         SDT           TP         TON       CHL-a
# count  103.000000  103.000000   103.000000  103.000000  103.000000
# mean    11.866019    4.322718   221.854369  100.368932   25.772621
# std      5.239585    4.940594   823.340713  125.403427   54.056045
# min      3.000000    0.030000     1.000000    6.000000    0.160000
# 25%      6.000000    0.675000     9.000000   21.000000    0.830000
# 50%     14.000000    2.000000    30.000000   45.000000    6.700000
# 75%     16.000000    7.250000   125.500000  126.000000   23.750000
# max     20.400000   19.000000  7912.000000  762.000000  405.300000

# %%
data.head()
# Out:
#    ID          NAME       TYPE  AREA  ZMEAN   ALT    LAT  TEMP   SDT  TP  TON  \
# 0   1         Rodeo       lake  0.09    3.6  1446  24.12  16.0  0.85  15   63
# 1   2      Comedero       lake  0.12    4.0  1446  24.12  16.0  1.20  18   36
# 2   3    La Ciénaga  reservoir  2.80    9.3  1212  24.47  17.5  1.00  25   45
# 3   4   Las Maderas  reservoir  9.60   31.3  1185  24.45  18.0  1.40  23   35
# 4   5  Campo Alegre  reservoir  3.20   14.4  1200  24.63  19.0  1.20  58   62
#
#    CHL-a
# 0   15.4
# 1   22.5
# 2    7.4
# 3   13.3
# 4   23.7

# %% [markdown]
# As we can see, the data is structured in 12 columns. The meaning of each column is described below:
# + **ID**: ID of the datapoint.
# + **NAME**: Name of the waterbody.
# + **TYPE**: Type of the waterbody.
# + **AREA**: Area, in $km^2$.
# + **ZMEAN**: Mean depth, in $m$.
# + **ALT**: Elevation, in $m$.
# + **LAT**: Latitude, $°S$.
# + **TEMP**: Annual mean air temperature, in $°C$.
# + **SDT**: Secchi disk transparency, in $m$.
# + **TP**: Total phosphorus, in $mg.m^{-3}$.
# + **TON**: Total organic nitrogen, in $\mu.M$
# + **CHL-a**: Total chlorophyll-a, in $mg.m^{-3}$.

# %%
sns.scatterplot(x=data['LAT'], y=data['SDT'], hue=data['TYPE'])
# Out:
# <AxesSubplot:xlabel='LAT', ylabel='SDT'>
